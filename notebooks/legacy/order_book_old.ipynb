# %%
# %run nb-env.ipynb
# Out:
# [2021-10-30T15:03:06.588155+08:00] Enviroment loaded. Working Dir: /Users/tzhu/work/lab/neo_world/notebooks
# Today is 2021-10-30, Working from 2020-10-14 to 2021-10-29

# %%
# %%time

date=today_date + 'T'
dc, df_init = init_data(month_ago_date, end_date, expire_days=7)
df = df_init.copy(deep=True)
# Out:
# Initializing data from 2021-09-23 to 2021-10-29...
# Merging all data...
# Start loading stock data from PG...
# Start loading adjfactor data from PG...
# Start loading daily_basic data from PG...
# Merging...
# Processing price variables...
# Calculating upstop data...
# Calculating MAs...
# Calculating list_days...
# CPU times: user 54.5 s, sys: 1.8 s, total: 56.3 s
# Wall time: 59.1 s

# %%
holding, dumped, orders = trade_summary(month_ago_date, end_date)
display(dumped)
display(holding.sort_values('hold_value', ascending=False))
# Out:
# From 2021-09-22 to 2021-10-28 summary:
# Total 21 stocks. Winning rate: 52.38%
# Total profit: -692.23, Max profit: 1711.15, Max lost: -1238.22.
# Current holding: 7 stocks. Current profit: -4655.7300000000005.
#                name trade_date_min trade_date_max  vol_sum  hold_value  \
# ts_code
# 000591.SZ    太阳能     2021-09-28     2021-09-30        0         0.0
# 300303.SZ  聚飞光电     2021-10-08     2021-10-18        0         0.0
# 600508.SH  上海能源     2021-10-12     2021-10-13        0         0.0
# 000812.SZ  陕西金叶     2021-10-13     2021-10-14        0         0.0
# 300102.SZ  乾照光电     2021-10-13     2021-10-14        0         0.0
# 300296.SZ    利亚德     2021-10-13     2021-10-14        0         0.0
# 002416.SZ    爱施德     2021-10-14     2021-10-15        0         0.0
# 300741.SZ  华宝股份     2021-10-14     2021-10-15        0         0.0
# 300162.SZ  雷曼光电     2021-10-14     2021-10-18        0         0.0
# 300346.SZ  南大光电     2021-10-15     2021-10-25        0         0.0
# ...
