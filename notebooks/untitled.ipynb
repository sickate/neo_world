# %%
import pandas_datareader as pdr

# %%
# no need
import requests
proxies = {
    'http': 'http://localhost:1087',
    'https': 'http://localhost:1087'
}
session = requests.Session()
session.proxies.update(proxies)
f = pdr.DataReader("F", "yahoo", "2016-01-01", "2016-12-31", session=session)

# %%
from yahoo_fin import stock_info as si

# %%
from pandas import ExcelWriter
import yfinance as yf
import pandas as pd
import datetime
import time

# %%
yf.pdr_override()

# Variables
tickers = si.tickers_sp500()
tickers = [item.replace(".", "-") for item in tickers] # Yahoo Finance uses dashes instead of dots
index_name = '^GSPC' # S&P 500
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()
exportList = pd.DataFrame(columns=['Stock', "RS_Rating", "50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High"])
returns_multiples = []

# %%
len(tickers)
# Out:
# 505

# %%
# Index Returns

index_df = pdr.get_data_yahoo(index_name, start_date, end_date)
index_df['Percent Change'] = index_df['Adj Close'].pct_change()
index_return = (index_df['Percent Change'] + 1).cumprod()[-1]

# Find top 30% performing stocks (relative to the S&P 500)
for ticker in tickers:
    # Download historical data as CSV for each stock (makes the process faster)
    df = pdr.get_data_yahoo(ticker, start_date, end_date)
    df.to_csv(f'{ticker}.csv')

    # Calculating returns relative to the market (returns multiple)
    df['Percent Change'] = df['Adj Close'].pct_change()
    stock_return = (df['Percent Change'] + 1).cumprod()[-1]
    
    returns_multiple = round((stock_return / index_return), 2)
    returns_multiples.extend([returns_multiple])
    
    print (f'Ticker: {ticker}; Returns Multiple against S&P 500: {returns_multiple}\n')
    time.sleep(1)

# Creating dataframe of only top 30%
rs_df = pd.DataFrame(list(zip(tickers, returns_multiples)), columns=['Ticker', 'Returns_multiple'])
rs_df['RS_Rating'] = rs_df.Returns_multiple.rank(pct=True) * 100
rs_df = rs_df[rs_df.RS_Rating >= rs_df.RS_Rating.quantile(.70)]
# Out:
# Ticker: A; Returns Multiple against S&P 500: 1.23
#
# Ticker: AAL; Returns Multiple against S&P 500: 1.15
#
# Ticker: AAP; Returns Multiple against S&P 500: 1.04
#
# Ticker: AAPL; Returns Multiple against S&P 500: 1.01
#
# Ticker: ABBV; Returns Multiple against S&P 500: 0.98
#
# Ticker: ABC; Returns Multiple against S&P 500: 0.9
#
# Ticker: ABMD; Returns Multiple against S&P 500: 0.85
#
# Ticker: ABT; Returns Multiple against S&P 500: 0.94
#
# Ticker: ACN; Returns Multiple against S&P 500: 1.07
#
# Ticker: ADBE; Returns Multiple against S&P 500: 1.07
#
# Ticker: ADI; Returns Multiple against S&P 500: 1.12
#
# Ticker: ADM; Returns Multiple against S&P 500: 1.07
#
# Ticker: ADP; Returns Multiple against S&P 500: 1.21
#
# Ticker: ADSK; Returns Multiple against S&P 500: 1.09
#
# Ticker: AEE; Returns Multiple against S&P 500: 0.83
#
# Ticker: AEP; Returns Multiple against S&P 500: 0.83
#
# Ticker: AES; Returns Multiple against S&P 500: 1.11
#
# Ticker: AFL; Returns Multiple against S&P 500: 1.15
#
# Ticker: AIG; Returns Multiple against S&P 500: 1.29
#
# Ticker: AIZ; Returns Multiple against S&P 500: 0.99
#
# Ticker: AJG; Returns Multiple against S&P 500: 1.0
#
# Ticker: AKAM; Returns Multiple against S&P 500: 0.82
#
# Ticker: ALB; Returns Multiple against S&P 500: 1.97
#
# Ticker: ALGN; Returns Multiple against S&P 500: 1.7
#
# Ticker: ALK; Returns Multiple against S&P 500: 1.13
#
# Ticker: ALL; Returns Multiple against S&P 500: 1.07
#
# Ticker: ALLE; Returns Multiple against S&P 500: 1.0
#
# Ticker: AMAT; Returns Multiple against S&P 500: 1.63
#
# Ticker: AMCR; Returns Multiple against S&P 500: 0.84
#
# Ticker: AMD; Returns Multiple against S&P 500: 1.04
#
# Ticker: AME; Returns Multiple against S&P 500: 1.04
#
# Ticker: AMGN; Returns Multiple against S&P 500: 0.75
#
# Ticker: AMP; Returns Multiple against S&P 500: 1.27
#
# Ticker: AMT; Returns Multiple against S&P 500: 0.86
#
# Ticker: AMZN; Returns Multiple against S&P 500: 0.81
#
# Ticker: ANET; Returns Multiple against S&P 500: 1.27
#
# Ticker: ANSS; Returns Multiple against S&P 500: 0.9
#
# Ticker: ANTM; Returns Multiple against S&P 500: 1.02
#
# Ticker: AON; Returns Multiple against S&P 500: 1.05
#
# Ticker: AOS; Returns Multiple against S&P 500: 1.1
#
# Ticker: APA; Returns Multiple against S&P 500: 0.93
#
# Ticker: APD; Returns Multiple against S&P 500: 0.76
#
# Ticker: APH; Returns Multiple against S&P 500: 1.03
#
# Ticker: APTV; Returns Multiple against S&P 500: 1.44
#
# Ticker: ARE; Returns Multiple against S&P 500: 0.92
#
# Ticker: ATO; Returns Multiple against S&P 500: 0.75
#
# Ticker: ATVI; Returns Multiple against S&P 500: 0.79
#
# Ticker: AVB; Returns Multiple against S&P 500: 1.14
#
# Ticker: AVGO; Returns Multiple against S&P 500: 1.16
#
# Ticker: AVY; Returns Multiple against S&P 500: 1.4
#
# Ticker: AWK; Returns Multiple against S&P 500: 0.94
#
# Ticker: AXP; Returns Multiple against S&P 500: 1.25
#
# Ticker: AZO; Returns Multiple against S&P 500: 1.05
#
# Ticker: BA; Returns Multiple against S&P 500: 0.98
#
# Ticker: BAC; Returns Multiple against S&P 500: 1.18
#
# Ticker: BAX; Returns Multiple against S&P 500: 0.68
#
# Ticker: BBWI; Returns Multiple against S&P 500: 2.16
#
# Ticker: BBY; Returns Multiple against S&P 500: 0.85
#
# Ticker: BDX; Returns Multiple against S&P 500: 0.71
#
# Ticker: BEN; Returns Multiple against S&P 500: 1.14
#
# Ticker: BF-B; Returns Multiple against S&P 500: 0.76
#
# Ticker: BIIB; Returns Multiple against S&P 500: 0.87
#
# Ticker: BIO; Returns Multiple against S&P 500: 1.16
#
# Ticker: BK; Returns Multiple against S&P 500: 1.09
#
# Ticker: BKNG; Returns Multiple against S&P 500: 0.92
#
# Ticker: BKR; Returns Multiple against S&P 500: 0.97
#
# Ticker: BLK; Returns Multiple against S&P 500: 1.19
#
# Ticker: BLL; Returns Multiple against S&P 500: 0.91
#
# Ticker: BMY; Returns Multiple against S&P 500: 0.83
#
# Ticker: BR; Returns Multiple against S&P 500: 0.92
#
# Ticker: BRK-B; Returns Multiple against S&P 500: 1.02
#
# Ticker: BSX; Returns Multiple against S&P 500: 0.82
#
# Ticker: BWA; Returns Multiple against S&P 500: 0.84
#
# Ticker: BXP; Returns Multiple against S&P 500: 1.01
#
# Ticker: C; Returns Multiple against S&P 500: 1.06
#
# Ticker: CAG; Returns Multiple against S&P 500: 0.7
#
# Ticker: CAH; Returns Multiple against S&P 500: 0.75
#
# Ticker: CARR; Returns Multiple against S&P 500: 1.46
#
# Ticker: CAT; Returns Multiple against S&P 500: 1.15
#
# Ticker: CB; Returns Multiple against S&P 500: 1.04
#
# Ticker: CBOE; Returns Multiple against S&P 500: 1.03
#
# Ticker: CBRE; Returns Multiple against S&P 500: 1.53
#
# Ticker: CCI; Returns Multiple against S&P 500: 0.92
#
# Ticker: CCL; Returns Multiple against S&P 500: 1.12
#
# Ticker: CDNS; Returns Multiple against S&P 500: 1.06
#
# Ticker: CDW; Returns Multiple against S&P 500: 1.24
#
# Ticker: CE; Returns Multiple against S&P 500: 1.19
#
# Ticker: CERN; Returns Multiple against S&P 500: 0.83
#
# Ticker: CF; Returns Multiple against S&P 500: 1.04
#
# Ticker: CFG; Returns Multiple against S&P 500: 1.31
#
# Ticker: CHD; Returns Multiple against S&P 500: 0.69
#
# Ticker: CHRW; Returns Multiple against S&P 500: 0.72
#
# Ticker: CHTR; Returns Multiple against S&P 500: 0.98
#
# Ticker: CI; Returns Multiple against S&P 500: 0.88
#
# Ticker: CINF; Returns Multiple against S&P 500: 1.12
#
# Ticker: CL; Returns Multiple against S&P 500: 0.8
#
# Ticker: CLX; Returns Multiple against S&P 500: 0.57
#
# Ticker: CMA; Returns Multiple against S&P 500: 1.37
#
# Ticker: CMCSA; Returns Multiple against S&P 500: 1.04
#
# Ticker: CME; Returns Multiple against S&P 500: 0.96
#
# Ticker: CMG; Returns Multiple against S&P 500: 1.22
#
# Ticker: CMI; Returns Multiple against S&P 500: 0.85
#
# Ticker: CMS; Returns Multiple against S&P 500: 0.8
#
# Ticker: CNC; Returns Multiple against S&P 500: 0.78
#
# Ticker: CNP; Returns Multiple against S&P 500: 1.0
#
# Ticker: COF; Returns Multiple against S&P 500: 1.87
#
# Ticker: COG; Returns Multiple against S&P 500: 0.64
#
# Ticker: COO; Returns Multiple against S&P 500: 1.02
#
# Ticker: COP; Returns Multiple against S&P 500: 1.11
#
# Ticker: COST; Returns Multiple against S&P 500: 1.04
#
# Ticker: CPB; Returns Multiple against S&P 500: 0.66
#
# Ticker: CPRT; Returns Multiple against S&P 500: 1.08
#
# Ticker: CRL; Returns Multiple against S&P 500: 1.46
#
# Ticker: CRM; Returns Multiple against S&P 500: 0.95
#
# Ticker: CSCO; Returns Multiple against S&P 500: 0.91
#
# Ticker: CSX; Returns Multiple against S&P 500: 1.0
#
# Ticker: CTAS; Returns Multiple against S&P 500: 0.94
#
# Ticker: CTLT; Returns Multiple against S&P 500: 1.05
#
# Ticker: CTSH; Returns Multiple against S&P 500: 0.84
#
# Ticker: CTVA; Returns Multiple against S&P 500: 1.3
#
# Ticker: CTXS; Returns Multiple against S&P 500: 0.56
#
# Ticker: CVS; Returns Multiple against S&P 500: 0.99
#
# Ticker: CVX; Returns Multiple against S&P 500: 0.9
#
# Ticker: CZR; Returns Multiple against S&P 500: 1.8
#
# Ticker: D; Returns Multiple against S&P 500: 0.76
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     666             if is_new_proxy_conn:
# --> 667                 self._prepare_proxy(conn)
#     668
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     931         conn.set_tunnel(self._proxy_host, self.port, self.proxy_headers)
# --> 932         conn.connect()
#     933
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLEOFError: EOF occurred in violation of protocol (_ssl.c:1108)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='finance.yahoo.com', port=443): Max retries exceeded with url: /quote/DAL/history?period1=1597138579&period2=1628711999&interval=1d&frequency=1d&filter=history (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1108)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-7-ebee5339e0e8> in <module>
#       8 for ticker in tickers:
#       9     # Download historical data as CSV for each stock (makes the process faster)
# ---> 10     df = pdr.get_data_yahoo(ticker, start_date, end_date)
#      11     df.to_csv(f'{ticker}.csv')
#      12
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/pandas_datareader/data.py in get_data_yahoo(*args, **kwargs)
#      78
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#      81
#      82
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/pandas_datareader/base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py in _read_one_data(self, url, params)
#     147         url = url.format(symbol)
#     148
# --> 149         resp = self._get_response(url, params=params, headers=self.headers)
#     150         ptrn = r"root\.App\.main = (.*?);\n}\(this\)\);"
#     151         try:
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/pandas_datareader/base.py in _get_response(self, url, params, headers)
#     153         last_response_text = ""
#     154         for _ in range(self.retry_count + 1):
# --> 155             response = self.session.get(
#     156                 url, params=params, headers=headers, timeout=self.timeout
#     157             )
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.virtualenv/neo_world/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='finance.yahoo.com', port=443): Max retries exceeded with url: /quote/DAL/history?period1=1597138579&period2=1628711999&interval=1d&frequency=1d&filter=history (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1108)')))

# %%
# Checking Minervini conditions of top 30% of stocks in given list
rs_stocks = rs_df['Ticker']
for stock in rs_stocks:    
    try:
        df = pd.read_csv(f'{stock}.csv', index_col=0)
        sma = [50, 150, 200]
        for x in sma:
            df["SMA_"+str(x)] = round(df['Adj Close'].rolling(window=x).mean(), 2)
        
        # Storing required values 
        currentClose = df["Adj Close"][-1]
        moving_average_50 = df["SMA_50"][-1]
        moving_average_150 = df["SMA_150"][-1]
        moving_average_200 = df["SMA_200"][-1]
        low_of_52week = round(min(df["Low"][-260:]), 2)
        high_of_52week = round(max(df["High"][-260:]), 2)
        RS_Rating = round(rs_df[rs_df['Ticker']==stock].RS_Rating.tolist()[0])
        
        try:
            moving_average_200_20 = df["SMA_200"][-20]
        except Exception:
            moving_average_200_20 = 0

        # Condition 1: Current Price > 150 SMA and > 200 SMA
        condition_1 = currentClose > moving_average_150 > moving_average_200
        
        # Condition 2: 150 SMA and > 200 SMA
        condition_2 = moving_average_150 > moving_average_200

        # Condition 3: 200 SMA trending up for at least 1 month
        condition_3 = moving_average_200 > moving_average_200_20
        
        # Condition 4: 50 SMA> 150 SMA and 50 SMA> 200 SMA
        condition_4 = moving_average_50 > moving_average_150 > moving_average_200
           
        # Condition 5: Current Price > 50 SMA
        condition_5 = currentClose > moving_average_50
           
        # Condition 6: Current Price is at least 30% above 52 week low
        condition_6 = currentClose >= (1.3*low_of_52week)
           
        # Condition 7: Current Price is within 25% of 52 week high
        condition_7 = currentClose >= (.75*high_of_52week)
        
        # If all conditions above are true, add stock to exportList
        if(condition_1 and condition_2 and condition_3 and condition_4 and condition_5 and condition_6 and condition_7):
            exportList = exportList.append({'Stock': stock, "RS_Rating": RS_Rating ,"50 Day MA": moving_average_50, "150 Day Ma": moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week}, ignore_index=True)
            print (stock + " made the Minervini requirements")
    except Exception as e:
        print (e)
        print(f"Could not gather data on {stock}")

exportList = exportList.sort_values(by='RS_Rating', ascending=False)
print('\n', exportList)
writer = ExcelWriter("ScreenOutput.xlsx")
exportList.to_excel(writer, "Sheet1")
writer.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-effba6919d5f> in <module>
#       1 # Checking Minervini conditions of top 30% of stocks in given list
# ----> 2 rs_stocks = rs_df['Ticker']
#       3 for stock in rs_stocks:
#       4     try:
#       5         df = pd.read_csv(f'{stock}.csv', index_col=0)
#
# NameError: name 'rs_df' is not defined
